# %%
import os, sys

# 👉 Set this to your project root folder
PROJECT_ROOT = r"C:\customer_churn_uplift\subscription_value_brain"

# Change working directory to project root (optional but helpful)
os.chdir(PROJECT_ROOT)

# Make sure project root is on sys.path
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print("CWD:", os.getcwd())
import pandas as pd

df = pd.read_parquet("data/processed/retail_clv.parquet")
df.head()
df.describe()
# Out:
# CWD: C:\customer_churn_uplift\subscription_value_brain
#         customer_id      Recency    Frequency       Monetary
# count   5881.000000  5881.000000  5881.000000    5881.000000
# mean   15314.674205   201.457745     6.287196    3017.076888
# std     1715.429759   209.474135    13.012879   14734.128619
# min    12346.000000     1.000000     1.000000       0.000000
# 25%    13833.000000    26.000000     1.000000     347.800000
# 50%    15313.000000    96.000000     3.000000     897.620000
# 75%    16797.000000   380.000000     7.000000    2304.180000
# max    18287.000000   739.000000   398.000000  608821.650000
