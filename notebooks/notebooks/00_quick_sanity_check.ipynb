# %%
import pandas as pd
from src.utils.io import load_telco_churn, load_online_retail, load_criteo_sample
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 from src.utils.io import load_telco_churn, load_online_retail, load_criteo_sample
#
# ModuleNotFoundError: No module named 'src'

# %%
telco = load_telco_churn()
retail = load_online_retail()
criteo = load_criteo_sample()

# %%
print("Telco shape:", telco.shape)
print("Retail shape:", retail.shape)
print("Criteo shape:", criteo.shape)

# %%
print(telco.head())
print(retail.head())
print(criteo.head())
